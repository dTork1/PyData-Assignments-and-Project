# %% [markdown]
# Call the numpy and pandas library

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Read the csv file as a dataframe using the read_csv method in pandas

# %%
df = pd.read_csv("PA.csv")

# %% [markdown]
# Call the dataframe to check

# %%
df
# Out:
#            date country state  county  fips  lat  long          locationId  \
# 0    2020-03-02      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 1    2020-03-03      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2    2020-03-04      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 3    2020-03-05      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 4    2020-03-06      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# ..          ...     ...   ...     ...   ...  ...   ...                 ...
# 496  2021-06-21      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 497  2021-06-22      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 498  2021-06-23      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 499  2021-06-24      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 500  2021-06-25      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
#
#      actuals.cases  actuals.deaths  ...  metrics.infectionRate  \
# ...

# %% [markdown]
# Check for the number of duplicated rows

# %%
df.duplicated().sum()
# Out:
# 20

# %% [markdown]
# Remove all columns that are completely empty

# %%
df.dropna(axis=1, how='all', inplace=True)

# %%
df
# Out:
#            date country state  fips          locationId  actuals.cases  \
# 0    2020-03-02      US    PA    42  iso1:us#iso2:us-pa            NaN
# 1    2020-03-03      US    PA    42  iso1:us#iso2:us-pa            NaN
# 2    2020-03-04      US    PA    42  iso1:us#iso2:us-pa            NaN
# 3    2020-03-05      US    PA    42  iso1:us#iso2:us-pa            NaN
# 4    2020-03-06      US    PA    42  iso1:us#iso2:us-pa            2.0
# ..          ...     ...   ...   ...                 ...            ...
# 496  2021-06-21      US    PA    42  iso1:us#iso2:us-pa      1215116.0
# 497  2021-06-22      US    PA    42  iso1:us#iso2:us-pa      1215239.0
# 498  2021-06-23      US    PA    42  iso1:us#iso2:us-pa      1215374.0
# 499  2021-06-24      US    PA    42  iso1:us#iso2:us-pa      1215735.0
# 500  2021-06-25      US    PA    42  iso1:us#iso2:us-pa            NaN
#
#      actuals.deaths  actuals.positiveTests  actuals.negativeTests  \
# ...

# %% [markdown]
# I struggled to replace the cells with "Not available" so I used the replace method replace the strings with a value of 100

# %%
df.replace("Not available", value=100, inplace=True)

# %%
df.replace("Not Available", value=100, inplace=True)

# %% [markdown]
# Missing values in columns that were not tottally empty were replaced with the median using the SimpleImputer from scikitlearn

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='median', missing_values=np.nan)
imputer = imputer.fit(df[['actuals.cases','actuals.deaths','actuals.positiveTests','actuals.negativeTests','actuals.hospitalBeds.currentUsageTotal','actuals.icuBeds.capacity','actuals.icuBeds.currentUsageTotal','actuals.icuBeds.currentUsageCovid','actuals.newCases','actuals.newCases','actuals.vaccinesDistributed','actuals.vaccinationsInitiated','actuals.vaccinationsCompleted','metrics.testPositivityRatio','metrics.contactTracerCapacityRatio','metrics.infectionRate','metrics.infectionRateCI90','metrics.icuHeadroomRatio','metrics.icuCapacityRatio','metrics.vaccinationsInitiatedRatio','metrics.vaccinationsCompletedRatio','actuals.newDeaths','actuals.vaccinesAdministered']])
df[['actuals.cases','actuals.deaths','actuals.positiveTests','actuals.negativeTests','actuals.hospitalBeds.currentUsageTotal','actuals.hospitalBeds.currentUsageCovid','actuals.icuBeds.capacity','actuals.icuBeds.currentUsageTotal','actuals.newCases','actuals.newCases','actuals.vaccinesDistributed','actuals.vaccinationsInitiated','actuals.vaccinationsCompleted','metrics.testPositivityRatio','metrics.contactTracerCapacityRatio','metrics.infectionRate','metrics.infectionRateCI90','metrics.icuHeadroomRatio','metrics.icuCapacityRatio','metrics.vaccinationsInitiatedRatio','metrics.vaccinationsCompletedRatio','actuals.newDeaths','actuals.vaccinesAdministered']] = imputer.transform(df[['actuals.cases','actuals.deaths','actuals.positiveTests','actuals.negativeTests','actuals.hospitalBeds.currentUsageTotal','actuals.icuBeds.capacity','actuals.icuBeds.currentUsageTotal','actuals.icuBeds.currentUsageCovid','actuals.newCases','actuals.newCases','actuals.vaccinesDistributed','actuals.vaccinationsInitiated','actuals.vaccinationsCompleted','metrics.testPositivityRatio','metrics.contactTracerCapacityRatio','metrics.infectionRate','metrics.infectionRateCI90','metrics.icuHeadroomRatio','metrics.icuCapacityRatio','metrics.vaccinationsInitiatedRatio','metrics.vaccinationsCompletedRatio','actuals.newDeaths','actuals.vaccinesAdministered']])
df
# Out:
#            date country state  fips          locationId  actuals.cases  \
# 0    2020-03-02      US    PA    42  iso1:us#iso2:us-pa       192374.0
# 1    2020-03-03      US    PA    42  iso1:us#iso2:us-pa       192374.0
# 2    2020-03-04      US    PA    42  iso1:us#iso2:us-pa       192374.0
# 3    2020-03-05      US    PA    42  iso1:us#iso2:us-pa       192374.0
# 4    2020-03-06      US    PA    42  iso1:us#iso2:us-pa            2.0
# ..          ...     ...   ...   ...                 ...            ...
# 496  2021-06-21      US    PA    42  iso1:us#iso2:us-pa      1215116.0
# 497  2021-06-22      US    PA    42  iso1:us#iso2:us-pa      1215239.0
# 498  2021-06-23      US    PA    42  iso1:us#iso2:us-pa      1215374.0
# 499  2021-06-24      US    PA    42  iso1:us#iso2:us-pa      1215735.0
# 500  2021-06-25      US    PA    42  iso1:us#iso2:us-pa       192374.0
#
#      actuals.deaths  actuals.positiveTests  actuals.negativeTests  \
# ...

# %%
df
# Out:
#            date country state  fips          locationId  actuals.cases  \
# 0    2020-03-02      US    PA    42  iso1:us#iso2:us-pa       192374.0
# 1    2020-03-03      US    PA    42  iso1:us#iso2:us-pa       192374.0
# 2    2020-03-04      US    PA    42  iso1:us#iso2:us-pa       192374.0
# 3    2020-03-05      US    PA    42  iso1:us#iso2:us-pa       192374.0
# 4    2020-03-06      US    PA    42  iso1:us#iso2:us-pa            2.0
# ..          ...     ...   ...   ...                 ...            ...
# 496  2021-06-21      US    PA    42  iso1:us#iso2:us-pa      1215116.0
# 497  2021-06-22      US    PA    42  iso1:us#iso2:us-pa      1215239.0
# 498  2021-06-23      US    PA    42  iso1:us#iso2:us-pa      1215374.0
# 499  2021-06-24      US    PA    42  iso1:us#iso2:us-pa      1215735.0
# 500  2021-06-25      US    PA    42  iso1:us#iso2:us-pa       192374.0
#
#      actuals.deaths  actuals.positiveTests  actuals.negativeTests  \
# ...

# %% [markdown]
# I checked to see if I had any more missing values

# %%
 df.isnull().values.any()
# Out:
# True

# %% [markdown]
# I checked which columns had the missing values

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['actuals.icuBeds.currentUsageCovid', 'metrics.caseDensity'], dtype='object')

# %% [markdown]
# I replaced missing values with the median

# %%
df.fillna(df['actuals.icuBeds.currentUsageCovid'].median(), inplace = True)

# %%
df.fillna(df['metrics.caseDensity'].median(), inplace = True)

# %% [markdown]
# I checked again to see if I would get any more missing values

# %%
df.columns[df.isnull().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# State name

# %%
df[df['date'] == "2021-06-16"]['state']
# Out:
# 491    PA
# Name: state, dtype: object

# %% [markdown]
# New cases

# %%
df[df['date'] == "2021-06-16"]['actuals.newCases']
# Out:
# 491    279.0
# Name: actuals.newCases, dtype: float64

# %% [markdown]
# New deaths

# %%
df[df['date'] == "2021-06-16"]['actuals.newDeaths']
# Out:
# 491    16.0
# Name: actuals.newDeaths, dtype: float64

# %% [markdown]
# Commulative Cases

# %%
df[df['date'] == "2021-06-16"]['actuals.cases']
# Out:
# 491    1214051.0
# Name: actuals.cases, dtype: float64

# %% [markdown]
# Commulative deaths

# %%
df[df['date'] == "2021-06-16"]['actuals.deaths']
# Out:
# 491    27582.0
# Name: actuals.deaths, dtype: float64

# %% [markdown]
# Vacinations Completed

# %%
df[df['date'] == "2021-06-16"]['metrics.vaccinationsCompletedRatio']
# Out:
# 491    0.472
# Name: metrics.vaccinationsCompletedRatio, dtype: float64

# %% [markdown]
# Vaccinations Iniated

# %%
df[df['date'] == "2021-06-16"]['metrics.vaccinationsInitiatedRatio']
# Out:
# 491    0.611
# Name: metrics.vaccinationsInitiatedRatio, dtype: float64

# %% [markdown]
# Import the matplot library

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = df['actuals.cases']
y = df['actuals.vaccinationsCompleted']

# %%
x
# Out:
# 0       192374.0
# 1       192374.0
# 2       192374.0
# 3       192374.0
# 4            2.0
#          ...
# 496    1215116.0
# 497    1215239.0
# 498    1215374.0
# 499    1215735.0
# 500     192374.0
# Name: actuals.cases, Length: 501, dtype: float64

# %%
y
# Out:
# 0      0.1915
# 1      0.1915
# 2      0.1915
# 3      0.1915
# 4      0.1915
#         ...
# 496    0.4850
# 497    0.4860
# 498    0.4870
# 499    0.4890
# 500    0.1915
# Name: metrics.vaccinationsCompletedRatio, Length: 501, dtype: float64

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('Actual Covid Cases')
ax.set_ylabel('Vaccinations Completed')
ax.set_title('Graph')
# Out:
# Text(0.5, 1.0, 'Graph')
